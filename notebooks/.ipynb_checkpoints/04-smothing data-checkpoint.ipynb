# %%
import pandas as pd
import matplotlib.pyplot as plt
# Display figures inline in Jupyter notebook
import seaborn as sns
import numpy as np
from pathlib import Path
from scipy import signal

# %%
import os,glob
g = os.getcwd()
g
path = 'D:\\repos\\CIAT\\IDB_PROJECT'
os.chdir(path)

# %%
df = pd.read_csv("Data_IDB/alldf_final.csv")
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.head()
df.ID = df.ID.astype(int)
df.head()
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# # Smoothing data

# %%
len(df["ID"].unique())
smooth_all = pd.DataFrame()
for fid in df["ID"].unique():
    db = df[df.ID == fid]
    smootdf = db[["NDVI","OSAVI","EVI","NWVI"]]
    smootdf = smootdf.apply(lambda x: signal.savgol_filter(x,9, 2, mode='nearest'),0,result_type='broadcast')
    smooth_merge_ID = pd.concat([db[["ID","date"]].reset_index(drop=True), smootdf.reset_index(drop=True)], axis=1)
    smooth_all = smooth_all.append(smooth_merge_ID.reset_index(drop=True))

# %%
smooth_all
melt_smooth = smooth_all.melt(["date","ID"])
melt_smooth.head()
# Out:
#         date     ID variable     value
# 0 2011-01-01  27611     NDVI  0.607092
# 1 2011-01-17  27611     NDVI  0.562223
# 2 2011-02-02  27611     NDVI  0.454664
# 3 2011-03-06  27611     NDVI  0.430091
# 4 2011-04-23  27611     NDVI  0.407838

# %% [markdown]
# set param to plot trends

# %%
# sns.set_style("white")
rc={"font.weight":"bold",'figure.figsize':(30, 6),'axes.labelsize': 28, 
    'font.size': 28,'axes.titlesize': 28,'legend.fontsize': 18, 'axes.titlesize': 28,
   "lines.linewidth": 2.5,'font.sans-serif': "Times New Roman"}
# sns.set()
sns.set(style="white", rc=rc,font_scale = 1.8)

DATE = pd.DataFrame({
    'inside':['2011-01-01','2012-01-01','2013-01-01','2014-01-01','2015-01-01','2016-01-01','2017-01-01','2018-01-01','2019-01-01']
})

DATE['inside'] = pd.to_datetime(DATE['inside'], format='%Y-%m-%d')
# DATE
# sns.set_style("white")
# sns.set_context("paper",rc=rc,font_scale = 1.5)

# %% [markdown]
# separate vegetation and water VIS

# %%
db_WI = melt_smooth[melt_smooth.variable == "NWVI"]
db_VI = melt_smooth[melt_smooth.variable != "NWVI"]
# Out:
#              date      ID variable     value
# 0      2011-01-01   27611     NDVI  0.607092
# 1      2011-01-17   27611     NDVI  0.562223
# 2      2011-02-02   27611     NDVI  0.454664
# 3      2011-03-06   27611     NDVI  0.430091
# 4      2011-04-23   27611     NDVI  0.407838
# ...           ...     ...      ...       ...
# 173242 2019-10-14  411411      EVI  0.255067
# 173243 2019-10-30  411411      EVI  0.259978
# 173244 2019-11-15  411411      EVI  0.268530
# 173245 2019-12-01  411411      EVI  0.291317
# 173246 2019-12-17  411411      EVI  0.315246
#
# [173247 rows x 4 columns]

# %%
# len(df["ID"].unique())
# for fid in df["ID"].unique():
#     db_ID = melt_smooth[melt_smooth.ID == fid]
#     p = sns.lineplot('date', 'value', hue='variable', style='variable',data=db_ID)
#     p.set(xlabel='Dates', ylabel='VIs value',title="Smooth Time serie for ID: " + str(db_ID.ID.iloc[0])) #+  str(df1.date.iloc[0][0:4])
#     # p.set_xticklabels(p.get_xticklabels(),rotation=30, horizontalalignment='right')

#     handles, labels = p.get_legend_handles_labels()
#     lgd = dict(zip(labels, handles))
#     p.legend(lgd.values(), lgd.keys(),loc='center left', bbox_to_anchor=(0.98, 0.5), ncol=1)
#     sns.despine()
#     for inside  in DATE.inside:
#         p.axvline(inside,color='r',label="start year")
#     # # p.xticks(rotation=45)
#     # p.tick_params(axis='x', labelrotation=90)
#     # figure = p.get_figure()
#     figure.savefig('Data_IDB/trends/TS_all-str' + (db_ID.ID.iloc[0])+ '.png', dpi=600)
# Out:
#              date     ID variable     value
# 0      2011-01-01  27611     NDVI  0.607092
# 1      2011-01-17  27611     NDVI  0.562223
# 2      2011-02-02  27611     NDVI  0.454664
# 3      2011-03-06  27611     NDVI  0.430091
# 4      2011-04-23  27611     NDVI  0.407838
# ...           ...    ...      ...       ...
# 115656 2019-09-28  27611      EVI  0.560918
# 115657 2019-10-14  27611      EVI  0.539684
# 115658 2019-10-30  27611      EVI  0.499296
# 115659 2019-11-15  27611      EVI  0.441442
# 115660 2019-12-01  27611      EVI  0.352889
#
# [489 rows x 4 columns]

# %% [markdown]
# # plot smooth trends

# %%
p = sns.lineplot('date', 'value', hue='variable', style='variable',
             data=db_WI)
p2 = p.twinx()
p.set(xlabel='Dates', ylabel='VIs value',title="Smooth Time serie for ID: " + str(db_ID.ID.iloc[0])) #+  str(df1.date.iloc[0][0:4])
# p.set_xticklabels(p.get_xticklabels(),rotation=30, horizontalalignment='right')

handles, labels = p.get_legend_handles_labels()
lgd = dict(zip(labels, handles))
p.legend(lgd.values(), lgd.keys(),loc='center left', bbox_to_anchor=(0.98, 0.5), ncol=1)
sns.despine()
for inside  in DATE.inside:
    p.axvline(inside,color='r',label="start year")
# # p.xticks(rotation=45)
# p.tick_params(axis='x', labelrotation=90)
# figure = p.get_figure()
figure.savefig('Data_IDB/trends/TS_all-str' + (db_ID.ID.iloc[0])+ '.png', dpi=600)

# %%
# df["ID"].unique()
# 27611
# for fid in df["ID"].unique():
#data from one ID
db_ID = melt_smooth[melt_smooth.ID == 27611]
db_WI = db_ID[db_ID.variable == "NWVI"]
db_VI = db_ID[db_ID.variable != "NWVI"]

# set a plot
p1 = sns.lineplot('date', 'value', hue='variable',data=db_VI,ci=None)
#label acis and title
p1.set(xlabel='Dates', ylabel='Vegetation index value',title="Smooth Time serie for ID: " + str(db_VI.ID.iloc[0]))

#specify we want to share the same x-axis
p2 = p1.twinx()
color = 'tab:red'
#line plot creation
p2 = sns.lineplot('date', 'value', hue='variable',data=db_WI, ci=None)
p2.set_ylabel('Water index value')
p2.get_lines()[0].set_color("firebrick")
# handles, labels = p1.get_legend_handles_labels()
# lgd1 = dict(zip(labels, handles))
# print(lgd1)
# p1.legend(lgd.values(), lgd.keys(),loc='center left', bbox_to_anchor=(0.005, 0.8), ncol=1)

handles, labels = p2.get_legend_handles_labels()
lgd2 = dict(zip(labels, handles))
print(lgd2)

# sns.despine()
# for inside  in DATE.inside:
#     p2.axvline(inside,color='r',label="start year")
# Out:
# {'variable': <matplotlib.lines.Line2D object at 0x000002024E637520>, 'NWVI': <matplotlib.lines.Line2D object at 0x000002024E637880>}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-e025f53e8f36> in <module>
#      29
#      30
# ---> 31 ax = p2.gca()
#      32 # leg = ax.get_legend()
#      33 # leg.legendHandles[0].set_color('red')
#
# AttributeError: 'AxesSubplot' object has no attribute 'gca'
