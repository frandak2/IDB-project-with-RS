# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import sidetable

# %%
import os,glob
g = os.getcwd()
g
path = 'D:\\repos\\CIAT\\IDB_PROJECT'
os.chdir(path)

# %% [markdown]
# # Read data base and merge

# %% [markdown]
# - Read the base line and create ID

# %%
Points = gpd.read_file("Data_IDB/new/Zona_influencia_DR.shp")
# print(Points.crs)
Points = Points.to_crs("EPSG:4326")
Points
######## ID para followUP1
ID = str(Points["cuest_id_b"]) + str(Points["parcela"])
str1 = [str(int) for int in Points["cuest_id_b"]] 
str2 = [str(int) for int in Points["parcela"]]
Points["ID"] = [int(s1 + s2) for s1, s2 in zip(str1, str2)]
ok = Points[Points['corregido2'].str.contains("ok")]
base = ok[["cultivo","superf_par","patca","correccion","corregido","corregido2","area","ID","temporary_",'geometry']]
base["time"] = "Baseline"
base
# base[base.ID == 386511]
# Out:
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#                cultivo  superf_par  patca                         correccion  \
# 0               tabaco    4.275839      1                            centrar
# 1                 yuca    1.886400      1                                 ok
# 2               sandia    1.886400      0                       Revisar área
# 3               tayota    3.772800      1                                 ok
# 4    tomate industrial    3.898560      0                                 ok
# ..                 ...         ...    ...                                ...
# 372          berenjena    0.943200      0  Revisar el área y tipo de cultivo
# 373             batata    1.886400      0                    Revisar el área
# 374            cebolla    0.880320      1           Revisar el área, centrar
# 375          berenjena    2.012160      0                                 ok
# 376          berenjena    2.200800      0                                 ok
#
#                                              corregido  \
# 0    se movió hacia arriba y la izquierda, la zona ...
# 1                                                   ok
# 2                            se movió hacía la derecha
# 3                                                   ok
# 4                                                   ok
# ..                                                 ...
# 372                            Revisar tipo de cultivo
# 373                                                 ok
# 374                               Se movió hacia abajo
# 375                                                 ok
# 376                                                 ok
#
#                       corregido2       area      ID  temporary_  \
# 0       ok, revisar tipo cultivo  15123.502  386311           1
# 1                             ok  15123.949  386512           1
# 2                             ok  11223.063  396011           1
# 3                             ok   8284.331  407811           0
# 4       ok, revisar tipo cultivo  15139.726  411411           1
# ..                           ...        ...     ...         ...
# 372  ok, revisar tipo de cultivo  15133.140  321413           1
# 373                           ok  15133.320  321412           1
# 374                  ok, arboles  15137.919  332612           1
# 375                           ok  12410.600  337521           1
# 376                 ok, arbustos   9493.377  351421           1
#
#                                               geometry      time
# 0    POLYGON ((-71.70753 18.89259, -71.70756 18.892...  Baseline
# 1    POLYGON ((-71.68327 18.70962, -71.68330 18.709...  Baseline
# 2    POLYGON ((-70.82647 18.39846, -70.82628 18.397...  Baseline
# 3    POLYGON ((-70.88998 18.74631, -70.89012 18.746...  Baseline
# 4    POLYGON ((-70.84436 18.43130, -70.84439 18.431...  Baseline
# ..                                                 ...       ...
# 372  POLYGON ((-71.24270 19.32214, -71.24273 19.321...  Baseline
# 373  POLYGON ((-71.23249 19.32311, -71.23252 19.322...  Baseline
# 374  POLYGON ((-70.97452 19.79906, -70.97455 19.798...  Baseline
# 375  POLYGON ((-70.50713 19.43071, -70.50670 19.431...  Baseline
# 376  POLYGON ((-70.51344 19.42558, -70.51353 19.425...  Baseline
#
# [377 rows x 11 columns]

# %%
base1 = pd.read_csv("Data_IDB/data_analisis/Panel_data_PATCA-DR-only_baseline.csv", encoding='latin-1')
ID = str(base1["cuest_id_b"]) + str(base1["parcela"])
str1 = [str(int) for int in base1["cuest_id_b"]] 
str2 = [str(int) for int in base1["parcela"]]
base1["ID"] = [int(s1 + s2) for s1, s2 in zip(str1, str2)]
######## ID2 para followUP2
ID = str(base1["cuest_id"]) + str(base1["parcela"])
str1 = [str(int) for int in base1["cuest_id"]] 
str2 = [str(int) for int in base1["parcela"]]
base1["ID2"] = [s1 + s2 for s1, s2 in zip(str1, str2)]
base1 = base1[["ID","ID2"]]
base1
# Out:
#          ID      ID2
# 0     27611  H095111
# 1     38911  H121311
# 2     39311  H121711
# 3     46611  H120011
# 4     48111  H121411
# ..      ...      ...
# 628  408411  H163911
# 629  408811  H177011
# 630  411111  H202211
# 631  411112  H202212
# 632  411411  H146311
#
# [633 rows x 2 columns]

# %%
base["ID2"] = None 
for fid in base.ID:
    ID2 = base1.ID2[base1.ID==fid].iloc[0]
    base["ID2"][base.ID==fid] = ID2
base

# %%
base[base.ID==386511]
base
# Out:
#                cultivo  superf_par  patca                         correccion  \
# 0               tabaco    4.275839      1                            centrar
# 1                 yuca    1.886400      1                                 ok
# 2               sandia    1.886400      0                       Revisar área
# 3               tayota    3.772800      1                                 ok
# 4    tomate industrial    3.898560      0                                 ok
# ..                 ...         ...    ...                                ...
# 372          berenjena    0.943200      0  Revisar el área y tipo de cultivo
# 373             batata    1.886400      0                    Revisar el área
# 374            cebolla    0.880320      1           Revisar el área, centrar
# 375          berenjena    2.012160      0                                 ok
# 376          berenjena    2.200800      0                                 ok
#
#                                              corregido  \
# 0    se movió hacia arriba y la izquierda, la zona ...
# 1                                                   ok
# 2                            se movió hacía la derecha
# 3                                                   ok
# 4                                                   ok
# ..                                                 ...
# 372                            Revisar tipo de cultivo
# 373                                                 ok
# 374                               Se movió hacia abajo
# 375                                                 ok
# 376                                                 ok
#
#                       corregido2       area      ID  temporary_  \
# 0       ok, revisar tipo cultivo  15123.502  386311           1
# 1                             ok  15123.949  386512           1
# 2                             ok  11223.063  396011           1
# 3                             ok   8284.331  407811           0
# 4       ok, revisar tipo cultivo  15139.726  411411           1
# ..                           ...        ...     ...         ...
# 372  ok, revisar tipo de cultivo  15133.140  321413           1
# 373                           ok  15133.320  321412           1
# 374                  ok, arboles  15137.919  332612           1
# 375                           ok  12410.600  337521           1
# 376                 ok, arbustos   9493.377  351421           1
#
#                                               geometry      time      ID2
# 0    POLYGON ((-71.70753 18.89259, -71.70756 18.892...  Baseline  H198411
# 1    POLYGON ((-71.68327 18.70962, -71.68330 18.709...  Baseline  H197312
# 2    POLYGON ((-70.82647 18.39846, -70.82628 18.397...  Baseline  H146411
# 3    POLYGON ((-70.88998 18.74631, -70.89012 18.746...  Baseline  H166811
# 4    POLYGON ((-70.84436 18.43130, -70.84439 18.431...  Baseline  H146311
# ..                                                 ...       ...      ...
# 372  POLYGON ((-71.24270 19.32214, -71.24273 19.321...  Baseline  H050313
# 373  POLYGON ((-71.23249 19.32311, -71.23252 19.322...  Baseline  H050312
# 374  POLYGON ((-70.97452 19.79906, -70.97455 19.798...  Baseline  H029112
# 375  POLYGON ((-70.50713 19.43071, -70.50670 19.431...  Baseline  H013821
# 376  POLYGON ((-70.51344 19.42558, -70.51353 19.425...  Baseline  H014021
#
# [377 rows x 12 columns]

# %% [markdown]
# - Read the follow-Up-1, create ID and remove duplicate ID

# %%
followup = pd.read_csv("Data_IDB/data_analisis/Panel_data_PATCA-DR-only_FU1.csv", encoding='latin-1')
followup2 = pd.read_csv("Data_IDB/data_analisis/Panel data PATCA-DR - only FU2_f.csv", encoding='latin-1')
followup2
# Out:
#      nform cuest_id  time  parcela             cultivo nombre_parcela  \
# 0      278    H0083     2       11                YUCA          KIARA
# 1      867    H0128     2       21      CILANTRO VERDE          CANCA
# 2      867    H0128     2       21              TABACO          CANCA
# 3      871    H0129     2       11                 NaN    FINCA TURIN
# 4      863    H0131     2       11            PLÃTANO          CANCA
# ..     ...      ...   ...      ...                 ...            ...
# 445   1056    H2212     2       11    HABICHUELA NEGRA   EL OTRO LADO
# 446   1056    H2212     2       11  MAIZ GRANO/MAZORCA   EL OTRO LADO
# 447   1054    H2213     2       11  MAIZ GRANO/MAZORCA  SABANA GRANDE
# 448   1054    H2213     2       11    HABICHUELA NEGRA  SABANA GRANDE
# 449   1049    H2214     2       11     HABICHUELA ROJA      LA VEREDA
#
#     provparcela_cod    munparcela_cod  superf_parcela_has  superficie_parcela  \
# 0         Espaillat  Gaspar Hernández             2.64096                42.0
# 1         Espaillat              Moca             1.44624                23.0
# 2         Espaillat              Moca             1.44624                23.0
# 3         Espaillat              Moca             1.25760                20.0
# 4         Espaillat              Moca             0.75456                12.0
# ..              ...               ...                 ...                 ...
# 445        San Juan        Vallejuelo             1.50912                24.0
# 446        San Juan        Vallejuelo             1.50912                24.0
# 447        San Juan        Vallejuelo             2.01216                32.0
# 448        San Juan        Vallejuelo             2.01216                32.0
# 449        San Juan        Vallejuelo             2.20080                35.0
#
#      ... year_siembra mixto_sino since_siembra  month_harvest year_harvest  \
# 0    ...       2019.0         No        2008.0      Noviembre       2019.0
# 1    ...       2019.0        SÃ­        2010.0          Julio       2019.0
# 2    ...       2019.0        SÃ­        2016.0              0          0.0
# 3    ...          NaN        NaN           NaN            NaN          NaN
# 4    ...       2016.0         No        1990.0            NaN          NaN
# ..   ...          ...        ...           ...            ...          ...
# 445  ...       2019.0         No        1997.0      Diciembre       2019.0
# 446  ...       2019.0         No        1997.0          Junio       2019.0
# 447  ...       2019.0         No        1970.0          Julio       2019.0
# 448  ...       2019.0         No        1970.0      Diciembre       2019.0
# 449  ...       2019.0         No        1990.0      Diciembre       2019.0
#
#      age female_head  transporte  tiempo_cant  tiempo_um
# 0     50           0       Motor         30.0    Minutos
# 1     60           0   Bicicleta          5.0    Minutos
# 2     60           0   Bicicleta          5.0    Minutos
# 3     36           0       A pie          1.0    Minutos
# 4     87           0       A pie          0.0    Minutos
# ..   ...         ...         ...          ...        ...
# 445   61           0       A pie         20.0    Minutos
# 446   61           0       A pie         20.0    Minutos
# 447   41           0       Motor         15.0    Minutos
# 448   41           0       Motor         15.0    Minutos
# 449   40           0       Motor         15.0    Minutos
#
# [450 rows x 23 columns]

# %%
followup[followup["cuest_id_b"]==3863]
# print(follwup.columns)
str1 = [str(int) for int in followup["cuest_id_b"]] 
str2 = [str(int) for int in followup["parcela"]]
followup["ID"] = [int(s1 + s2) for s1, s2 in zip(str1, str2)]
FU1 = followup[["ID","time",'temporary_crop',"cultivo"]]
print(len(FU1))
ID = FU1["ID"].drop_duplicates()
FU1 = FU1.loc[ID.index.tolist()]
print(len(FU1))
FU1[FU1.ID == 386511]
# Out:
# 646
# 441
#          ID           time  temporary_crop cultivo
# 473  386511  1. Follow-up1               1    mani

# %%
FU1["ID2"] = None 
for fid in FU1.ID:
    ID2 = base1.ID2[base1.ID==fid].iloc[0]
    FU1["ID2"][FU1.ID==fid] = ID2
FU1

# %%
FU1
# Out:
#          ID           time  temporary_crop            cultivo      ID2
# 0     27611  1. Follow-up1               0              pasto  H095111
# 2     38911  1. Follow-up1               0              mango  H121311
# 3     39311  1. Follow-up1               0              mango  H121711
# 4     46611  1. Follow-up1               0            plátano  H120011
# 5     48111  1. Follow-up1               0              pasto  H121411
# ..      ...            ...             ...                ...      ...
# 640  408411  1. Follow-up1               0              pasto  H163911
# 641  408811  1. Follow-up1               1            guandul  H177011
# 643  411111  1. Follow-up1               1              arroz  H202211
# 644  411112  1. Follow-up1               1             batata  H202212
# 645  411411  1. Follow-up1               1  tomate industrial  H146311
#
# [441 rows x 5 columns]

# %%
# followup2[followup2["cuest_id"]==3863]
# print(follwup.columns)
str1 = [str(int) for int in followup2["cuest_id"]] 
str2 = [str(int) for int in followup2["parcela"]]
followup2["ID2"] = [s1 + s2 for s1, s2 in zip(str1, str2)]
FU2 = followup2[["ID2","time",'temporary_crop',"cultivo"]]
print(len(FU2))
ID = FU2["ID2"].drop_duplicates()
FU2 = FU2.loc[ID.index.tolist()]
print(len(FU2))
FU2[FU2.ID2 == "H197311"]
# Out:
# 450
# 304
#          ID2  time temporary_crop  cultivo
# 389  H197311     2      Temporero  GUANDUL

# %%
base["ID2"] = None 
for fid in base.ID:
    ID2 = base1.ID2[base1.ID==fid].iloc[0]
    base["ID2"][base.ID==fid] = ID2
base
# Out:
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# ...
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-21-08e2c3b70d9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["ID2"][base.ID==fid] = ID2
# C:\Users\fmontenegro\Miniconda3\envs\GEE\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
#                cultivo  superf_par  patca                         correccion  \
# 0               tabaco    4.275839      1                            centrar
# 1                 yuca    1.886400      1                                 ok
# 2               sandia    1.886400      0                       Revisar área
# 3               tayota    3.772800      1                                 ok
# 4    tomate industrial    3.898560      0                                 ok
# ..                 ...         ...    ...                                ...
# 372          berenjena    0.943200      0  Revisar el área y tipo de cultivo
# 373             batata    1.886400      0                    Revisar el área
# 374            cebolla    0.880320      1           Revisar el área, centrar
# 375          berenjena    2.012160      0                                 ok
# 376          berenjena    2.200800      0                                 ok
#
#                                              corregido  \
# 0    se movió hacia arriba y la izquierda, la zona ...
# 1                                                   ok
# 2                            se movió hacía la derecha
# 3                                                   ok
# 4                                                   ok
# ..                                                 ...
# 372                            Revisar tipo de cultivo
# 373                                                 ok
# 374                               Se movió hacia abajo
# 375                                                 ok
# 376                                                 ok
#
#                       corregido2       area      ID  temporary_  \
# 0       ok, revisar tipo cultivo  15123.502  386311           1
# 1                             ok  15123.949  386512           1
# 2                             ok  11223.063  396011           1
# 3                             ok   8284.331  407811           0
# 4       ok, revisar tipo cultivo  15139.726  411411           1
# ..                           ...        ...     ...         ...
# 372  ok, revisar tipo de cultivo  15133.140  321413           1
# 373                           ok  15133.320  321412           1
# 374                  ok, arboles  15137.919  332612           1
# 375                           ok  12410.600  337521           1
# 376                 ok, arbustos   9493.377  351421           1
#
#                                               geometry      time      ID2
# 0    POLYGON ((-71.70753 18.89259, -71.70756 18.892...  Baseline  H198411
# 1    POLYGON ((-71.68327 18.70962, -71.68330 18.709...  Baseline  H197312
# 2    POLYGON ((-70.82647 18.39846, -70.82628 18.397...  Baseline  H146411
# 3    POLYGON ((-70.88998 18.74631, -70.89012 18.746...  Baseline  H166811
# 4    POLYGON ((-70.84436 18.43130, -70.84439 18.431...  Baseline  H146311
# ..                                                 ...       ...      ...
# 372  POLYGON ((-71.24270 19.32214, -71.24273 19.321...  Baseline  H050313
# 373  POLYGON ((-71.23249 19.32311, -71.23252 19.322...  Baseline  H050312
# 374  POLYGON ((-70.97452 19.79906, -70.97455 19.798...  Baseline  H029112
# 375  POLYGON ((-70.50713 19.43071, -70.50670 19.431...  Baseline  H013821
# 376  POLYGON ((-70.51344 19.42558, -70.51353 19.425...  Baseline  H014021
#
# [377 rows x 12 columns]

# %% [markdown]
# # Merge dateset

# %% [markdown]
# - Base line with FOLLOWUP1

# %%
survey = base.merge(FU1,how='inner', on="ID")
print(len(survey))
survey.columns
# Out:
# 377
# Index(['cultivo_x', 'superf_par', 'patca', 'correccion', 'corregido',
#        'corregido2', 'area', 'ID', 'temporary_', 'geometry', 'time_x', 'ID2_x',
#        'time_y', 'temporary_crop', 'cultivo_y', 'ID2_y'],
#       dtype='object')

# %% [markdown]
# - Base line with FOLLOWUP2

# %%
survey2 = base.merge(FU2,how='inner', on="ID2")
print(len(survey2))
survey2.columns
# Out:
# 268
# Index(['cultivo_x', 'superf_par', 'patca', 'correccion', 'corregido',
#        'corregido2', 'area', 'ID', 'temporary_', 'geometry', 'time_x', 'ID2',
#        'time_y', 'temporary_crop', 'cultivo_y'],
#       dtype='object')

# %% [markdown]
# FOLLOWUP1 with FOLLOWUP2

# %%
survey3 = FU1.merge(survey2,how='inner', on="ID2")
print(len(survey3))
survey3.columns
# Out:
# 268
# Index(['ID_x', 'time', 'temporary_crop_x', 'cultivo', 'ID2', 'cultivo_x',
#        'superf_par', 'patca', 'correccion', 'corregido', 'corregido2', 'area',
#        'ID_y', 'temporary_', 'geometry', 'time_x', 'time_y',
#        'temporary_crop_y', 'cultivo_y'],
#       dtype='object')

# %%
survey["trends"] = "nan"
survey.trends[survey.temporary_ ==  survey.temporary_crop] = "trend"
survey.trends[survey.temporary_ !=  survey.temporary_crop] = "no trend"
# Out:
# <ipython-input-43-eb35212033d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey.trends[survey.temporary_ ==  survey.temporary_crop] = "trend"
# <ipython-input-43-eb35212033d3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey.trends[survey.temporary_ !=  survey.temporary_crop] = "no trend"

# %%
survey2["trends"] = "nan"
survey2.trends[survey2.temporary_ ==  survey2.temporary_crop] = "trend"
survey2.trends[survey2.temporary_ !=  survey2.temporary_crop] = "no trend"
survey2.head()
# Out:
# <ipython-input-46-debb087c1ea6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey2.trends[survey2.temporary_ ==  survey2.temporary_crop] = "trend"
# <ipython-input-46-debb087c1ea6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey2.trends[survey2.temporary_ !=  survey2.temporary_crop] = "no trend"
#            cultivo_x  superf_par  patca    correccion  \
# 0             tabaco    4.275839      1       centrar
# 1               yuca    1.886400      1            ok
# 2             sandia    1.886400      0  Revisar área
# 3             tayota    3.772800      1            ok
# 4  tomate industrial    3.898560      0            ok
#
#                                            corregido  \
# 0  se movió hacia arriba y la izquierda, la zona ...
# 1                                                 ok
# 2                          se movió hacía la derecha
# 3                                                 ok
# 4                                                 ok
#
#                  corregido2       area      ID  temporary_  \
# 0  ok, revisar tipo cultivo  15123.502  386311           1
# 1                        ok  15123.949  386512           1
# 2                        ok  11223.063  396011           1
# 3                        ok   8284.331  407811           0
# 4  ok, revisar tipo cultivo  15139.726  411411           1
#
#                                             geometry    time_x      ID2  \
# 0  POLYGON ((-71.70753 18.89259, -71.70756 18.892...  Baseline  H198411
# 1  POLYGON ((-71.68327 18.70962, -71.68330 18.709...  Baseline  H197312
# 2  POLYGON ((-70.82647 18.39846, -70.82628 18.397...  Baseline  H146411
# 3  POLYGON ((-70.88998 18.74631, -70.89012 18.746...  Baseline  H166811
# 4  POLYGON ((-70.84436 18.43130, -70.84439 18.431...  Baseline  H146311
#
#    time_y temporary_crop          cultivo_y    trends
# 0       2      Temporero               AJÃ  no trend
# 1       2      Temporero               YUCA  no trend
# 2       2     Permanente           PLÃTANO  no trend
# 3       2     Permanente           AGUACATE  no trend
# 4       2      Temporero  TOMATE INDUSTRIAL  no trend

# %%
survey3["trends"] = "nan"
survey3.trends[survey3.temporary_crop_x ==  survey3.temporary_crop_y] = "trend"
survey3.trends[survey3.temporary_crop_x !=  survey3.temporary_crop_y] = "no trend"
survey3.head()
# Out:
# <ipython-input-47-093c26c9dde5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey3.trends[survey3.temporary_crop_x ==  survey3.temporary_crop_y] = "trend"
# <ipython-input-47-093c26c9dde5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey3.trends[survey3.temporary_crop_x !=  survey3.temporary_crop_y] = "no trend"
#     ID_x           time  temporary_crop_x  cultivo      ID2 cultivo_x  \
# 0  27611  1. Follow-up1                 0    pasto  H095111     pasto
# 1  38911  1. Follow-up1                 0    mango  H121311     mango
# 2  39311  1. Follow-up1                 0    mango  H121711     mango
# 3  46611  1. Follow-up1                 0  plátano  H120011      cero
# 4  51511  1. Follow-up1                 0  plátano  H121811   plátano
#
#    superf_par  patca                                         correccion  \
# 0    7.545599      0  Punto sobre la vía, mover hacía la derecha o i...
# 1    1.697760      0  mover hacia el centro del cultivo y revisar el...
# 2    4.401599      0                  mover hacia el centro del cultivo
# 3    2.483760      0                                       revisar área
# 4    1.886400      0                                                 ok
#
#                                            corregido corregido2       area  \
# 0  Se movió hacia la izquierda, zona de influenci...         ok  10019.219
# 1                        Se movió hacia la izquierda         ok  15146.586
# 2                               Se movió hacia abajo         ok  14407.398
# 3                                                 ok         ok   5979.754
# 4                                                 ok         ok  24270.634
#
#     ID_y  temporary_                                           geometry  \
# 0  27611           0  POLYGON ((-71.45845 19.52884, -71.45852 19.528...
# 1  38911           0  POLYGON ((-70.32475 18.29156, -70.32478 18.291...
# 2  39311           0  POLYGON ((-70.45914 18.22987, -70.45877 18.229...
# 3  46611           0  POLYGON ((-70.49775 18.21891, -70.49710 18.218...
# 4  51511           0  POLYGON ((-70.45014 18.22665, -70.45062 18.225...
#
#      time_x  time_y temporary_crop_y cultivo_y    trends
# 0  Baseline       2       Permanente     PASTO  no trend
# 1  Baseline       2       Permanente     MANGO  no trend
# 2  Baseline       2       Permanente  AGUACATE  no trend
# 3  Baseline       2       Permanente     MANGO  no trend
# 4  Baseline       2       Permanente  PLÃTANO  no trend

# %% [markdown]
# - Select ID with trend

# %%
survey[(survey.ID==396011) & (survey.trends=="trend")]
# type(trends.ID[0])

# %%
survey[survey.ID==396011]

# %% [markdown]
# # read predictions kendal and CCDC

# %% [markdown]
# - read Kendal

# %%
deseason_kendal = pd.read_csv("Data_IDB/deseason_kendal_osavi_14-2019.csv")
deseason_kendal.head()
# Out:
#    Unnamed: 0     ID   trend_Ori  Pvalue_Ori trends_Mod_yue  Pvalue_Mod_yue  \
# 0           0  27611    no trend    0.979339       no trend        0.954929
# 1           1  38911    no trend    0.052445     increasing        0.015385
# 2           2  39311    no trend    0.936714       no trend        0.900963
# 3           3  46611  increasing    0.007643     increasing        0.000722
# 4           4  51511    no trend    0.914340       no trend        0.891092
#
#   trends_Mod_rao  Pvalue_Mod_rao trends_seasonal  Pvalue_seasonal  \
# 0       no trend        0.986213        no trend         0.566917
# 1       no trend        0.263291        no trend         0.298618
# 2       no trend        0.953198        no trend         0.520703
# 3       no trend        0.066535      increasing         0.012589
# 4       no trend        0.932372        no trend         0.803463
#
#             test
# 0  mandal kendal
# 1  mandal kendal
# 2  mandal kendal
# 3  mandal kendal
# 4  mandal kendal

# %% [markdown]
# kendal mode YUE

# %%
deseason_kendal["trends"] = "Nan"
deseason_kendal.trends[deseason_kendal.trends_Mod_yue!="no trend"] = "trend"
deseason_kendal.trends[deseason_kendal.trends_Mod_yue=="no trend"] = "no trend"
deseason_kendal.columns = ['Unnamed: 0', 'ID_x', 'trend_Ori', 'Pvalue_Ori', 'trends_Mod_yue',
       'Pvalue_Mod_yue', 'trends_Mod_rao', 'Pvalue_Mod_rao', 'trends_seasonal',
       'Pvalue_seasonal', 'test', 'trends']
# Out:
# <ipython-input-57-f49db9fb8031>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deseason_kendal.trends[deseason_kendal.trends_Mod_yue!="no trend"] = "trend"
# <ipython-input-57-f49db9fb8031>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deseason_kendal.trends[deseason_kendal.trends_Mod_yue=="no trend"] = "no trend"

# %%
validacion_deseason_kendal= deseason_kendal.merge(survey3,how='inner', on=["ID_x","trends"])
print('deseason_kendal: ',(len(validacion_deseason_kendal)*100)/377)
# Out:
# deseason_kendal:  34.48275862068966

# %% [markdown]
# - read CCDC

# %%
CCDC = pd.read_csv("Data_IDB/iv_CCDC_2014.csv")
len(CCDC.ID.unique())
# Out:
# 377

# %%
count = CCDC.groupby("ID").count()
count
count["trends"] = None
count.trends[count.numObs==1]="trend"
count.trends[count.numObs>1]="no trend"
# count["ID"] = count.index
count = count[["trends"]]
count
# Out:
# <ipython-input-60-98c3baa8ebe0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   count.trends[count.numObs==1]="trend"
# <ipython-input-60-98c3baa8ebe0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   count.trends[count.numObs>1]="no trend"
#           trends
# ID
# 27611      trend
# 38911   no trend
# 39311      trend
# 46611      trend
# 51511      trend
# ...          ...
# 408412  no trend
# 408811     trend
# 411111     trend
# 411112     trend
# 411411  no trend
#
# [377 rows x 1 columns]

# %%
trends_CCDC= CCDC.merge(count,how='inner', on=["ID"])
print(trends_CCDC.shape)
trends_CCDC.drop_duplicates("ID",inplace=True)
print(trends_CCDC.shape)
# CCDC["trends"] = "NaN"
# CCDC.trends[CCDC.tBreak.isna()] = "trend"
# CCDC.trends[CCDC.tBreak.notna()] = "no trend"
# CCDC
# CCDC[CCDC['ID'] == 268811]
trends_CCDC.columns = ['Unnamed: 0', 'ID_x', 'patca', 'geometry', 'tStart', 'tEnd', 'tBreak',
       'numObs', 'trends']
# Out:
# (426, 9)
# (377, 9)

# %%
validacion_CCDC= trends_CCDC.merge(survey3,how='inner', on=["ID_x","trends"])
(len(validacion_CCDC)*100)/377
# Out:
# 8.753315649867375

# %%
no_merge = survey[survey.ID.isin(validacion_CCDC.ID)]
no_merge = no_merge[["ID","cultivo_x","cultivo_y","superf_par", "area",	"correccion","corregido", "corregido2", "patca","temporary_","temporary_crop","trends","geometry"]]
# no_merge.to_csv("Data_IDB/merge_2014.csv",encoding='latin-1')

# %%
gdf = gpd.GeoDataFrame(no_merge, geometry='geometry')
# gdf.to_file("Data_IDB/new/merge_2014.shp")

# %%
# validacion_CCDC= CCDC.merge(merge,how='inner', on=["ID"])
validacion_CCDC.columns

# %%
table = trends_CCDC.stb.freq(['trends'])
# table.to_csv("Data_IDB/validacion/pactavs_all.csv")
# trends_CCDC[["trends"]]

table

# %%
survey.stb.freq(['trends'])
# survey.sort_values("ID")
# survey[["trends"]]

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

survey3.sort_values("ID_x",inplace=True,ignore_index=True)
trends_CCDC.sort_values("ID_x",inplace=True,ignore_index=True)
deseason_kendal.sort_values("ID_x",inplace=True,ignore_index=True)
# survey[trends_CCDC.ID == survey.ID]

df = pd.DataFrame()
df["y_true"] = survey.trends
# df["y_pred"] = trends_CCDC.trends
df["y_pred"] = deseason_kendal.trends
df.shape
confusion_matrix = pd.crosstab(df["y_true"] , df['y_pred'], rownames=['Actual'], colnames=['Predicción'])

sn.heatmap(confusion_matrix,annot=True, fmt="d")
plt.show()

(58+150)/(58+150+42+127)
# Out:
# 0.5517241379310345

# %%
df = pd.DataFrame()
str1 = [str(int) for int in survey["patca"]] 
str2 = [str(int) for int in survey["trends"]]
df["y_true"]= [s1 + s2 for s1, s2 in zip(str1, str2)]
str1 = [str(int) for int in trends_CCDC["patca"]] 
str2 = [str(int) for int in trends_CCDC["trends"]]
df["y_pred"] = [s1 + s2 for s1, s2 in zip(str1, str2)]
# df['y_true'] = df['y_true'].map({'0trend': 3, '0no trend': 2,'1trend': 1, '1no trend': 0})
# df['y_pred'] = df['y_pred'].map({'0trend': 3, '0no trend': 2,'1trend': 1, '1no trend': 0})
confusion_matrix = pd.crosstab(df["y_true"] , df['y_pred'], rownames=['Actual'], colnames=['Predicted'])

sn.heatmap(confusion_matrix,annot=True, fmt="d")
plt.show()

# %%
data_month = pd.read_csv("Data_IDB/data_monthly.csv")
data_month.ID = data_month.ID.astype(int)
data_month = data_month[data_month.date<"2015-01-01"]

data_month.head()

# %%
data_month_merge = data_month.merge(survey,how='inner', on=["ID"])
data_month_merge.columns
data_month_merge = data_month_merge[["ID","NDVI","OSAVI","EVI","patca","trends","temporary_crop"]]
data_month_merge.head()

# %%
group = data_month_merge.groupby(["patca","temporary_crop"]).mean()
group
